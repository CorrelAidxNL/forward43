# %%
# %load_ext autoreload
# %autoreload 2

# %%
import forward43.survey_monkey

# %%
import pprint

# %%
access_token = "1llF9xA7seKwmqyR3jXxrlWnn1cpsEa.BPLXJqeRoyEpW9oZse2YnMFX.JqrelMJHt0rb1WfXONiDJtReb.IenFsj2jFrOPpViYThxYlqeUizTkOUDyKT58wRFk5nSyc"

# %%
from scraper_masterpeace import MasterpeaceScraper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-776a73085802> in <module>
# ----> 1 from scraper_masterpeace import MasterpeaceScraper
#
# ~\OneDrive\Bureaublad\forward43\forward43\scraper_masterpeace.py in <module>
#       3
#       4 from surveymonkey import client
# ----> 5 from scraper import ForwardScraper
#       6
#       7
#
# ~\OneDrive\Bureaublad\forward43\forward43\scraper.py in <module>
#       8 from fp.fp          import FreeProxy
#       9
# ---> 10 from forward43.hparams        import user_agent_list, accept_list
#      11 from forward43.data.data_path import DATA_DIRECTORY
#      12 from forward43.logs.log_path import LOG_DIRECTORY
#
# ModuleNotFoundError: No module named 'forward43.hparams'; 'forward43' is not a package

# %%
survey_details = survey_monkey.survey_details

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(survey_details.json())
# Out:
# {   'analyze_url': 'https://www.surveymonkey.com/analyze/2s3XUKv_2FMXjHTLdk0ddaveYyq1FRlZNVzBW4vP_2BjgCM_3D',
#     'buttons_text': {   'done_button': 'Done',
#                         'exit_button': 'Exit',
#                         'next_button': 'Next',
#                         'prev_button': 'Prev'},
#     'category': '',
#     'collect_url': 'https://www.surveymonkey.com/collect/list?sm=2s3XUKv_2FMXjHTLdk0ddaveYyq1FRlZNVzBW4vP_2BjgCM_3D',
#     'custom_variables': {},
#     'date_created': '2020-11-20T09:32:00',
#     'date_modified': '2021-01-22T02:28:00',
#     'edit_url': 'https://www.surveymonkey.com/create/?sm=2s3XUKv_2FMXjHTLdk0ddaveYyq1FRlZNVzBW4vP_2BjgCM_3D',
#     'folder_id': '0',
#     'footer': True,
#     'href': 'https://api.surveymonkey.com/v3/surveys/297005313',
#     'id': '297005313',
#     'is_owner': True,
#     'language': 'en',
#     'nickname': '',
#     'page_count': 8,
#     'pages': [   {   'description': '<div>Dear Club leader,<br><br>Welcome to '
# ...
